# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel("~/code/ruc/homework/20220221-Kepler/太阳系行星数据与开普勒.xlsx", usecols="A:C", index_col=0)
df
# Out:
#           R        T
# 水星    0.387    0.240
# 金星    0.723    0.615
# 地球    1.000    1.000
# 火星    1.524    1.880
# 木星    5.200   11.860
# 土星    9.539   29.460
# 天王星  19.200   84.000
# 海王星  30.100  165.000
# 冥王星  39.500  248.000

# %%
df["R_3"] = df.R ** 3
df["T_2"] = df["T"]** 2

df.R_3 / df.T_2
# Out:
# 水星     1.006260
# 金星     0.999228
# 地球     1.000000
# 火星     1.001473
# 木星     0.999633
# 土星     1.000099
# 天王星    1.003102
# 海王星    1.001686
# 冥王星    1.002047
# dtype: float64

# %%
sns.set_style("darkgrid")
fig, ax = plt.subplots(1, 1)
ax.scatter(x="R_3", y="T_2", s=100, data=df)
ax.set_xscale('log')
ax.set_yscale('log')
plt.show()
